# %%
print('"hola mundo"')
# Out:
# "hola mundo"

# %%
numero = 12

if numero > 5:
    print('Es mayor que 5')
else:
    print("Es menor que 5")
# Out:
# Es mayor que 5

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
my_list = [1,2.1545,3, 'orlando', True]
print(my_list[3])

my_list[3] = 'miguelon'
print(my_list[3])
# Out:
# orlando
# miguelon

# %%
import pandas as pd

pd.read_excel('./DataFiles/Hungarian_Switzerland.xlsx')
# Out:
#       Unnamed: 0  age        sex  Chest pain type    resting blood pressure  \
# 0      Patient 1         28    1                   2                    130
# 1      Patient 2         29    1                   2                    120
# 2      Patient 3         29    1                   2                    140
# 3      Patient 4         30    0                   1                    170
# 4      Patient 5         31    0                   2                    100
# ..           ...        ...  ...                 ...                    ...
# 289  Patient 290         52    1                   4                    160
# 290  Patient 291         54    0                   3                    130
# 291  Patient 292         56    1                   4                    155
# 292  Patient 293         58    0                   2                    180
# 293  Patient 294         65    1                   4                    130
#
# ...
